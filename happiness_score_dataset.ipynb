# %% [markdown]
# # happiness score dataset

# %%
#importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#read data in dataframe
df=pd.read_csv('happiness_score_dataset.csv')
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample(3)
# Out:
#                      Country                           Region  Happiness Rank  \
# 107  Palestinian Territories  Middle East and Northern Africa             108
# 38                    Kuwait  Middle East and Northern Africa              39
# 137                     Mali               Sub-Saharan Africa             138
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 107            4.715         0.04394                   0.59867  0.92558
# 38             6.295         0.04456                   1.55422  1.16594
# 137            3.995         0.05602                   0.26074  1.03526
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 107                   0.66015  0.24499                        0.12905
# 38                    0.72492  0.55499                        0.25609
# 137                   0.20583  0.38857                        0.12352
#
#      Generosity  Dystopia Residual
# 107     0.11251            2.04384
# ...

# %%
df.shape
# Out:
# (158, 12)

# %% [markdown]
# there are 158 rows and 12 columns

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# It gives all column name from data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# data type - float, integer and object are present.
# float- 9
# integer- 1
# object-2

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# No null value is present

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df["Country"].nunique()
# Out:
# 158

# %%
# droping unwanted/unnecessary colums from dataset
df.drop(['Country', 'Region', 'Happiness Rank'],axis=1, inplace=True)

# %%
df.shape
# Out:
# (158, 9)

# %% [markdown]
# we droped 3 column which we doesnt required for our prediction

# %%
df.columns
# Out:
# Index(['Happiness Score', 'Standard Error', 'Economy (GDP per Capita)',
#        'Family', 'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Happiness Score  Standard Error  Economy (GDP per Capita)      Family  \
# count       158.000000      158.000000                158.000000  158.000000
# mean          5.375734        0.047885                  0.846137    0.991046
# std           1.145010        0.017146                  0.403121    0.272369
# min           2.839000        0.018480                  0.000000    0.000000
# 25%           4.526000        0.037268                  0.545808    0.856823
# 50%           5.232500        0.043940                  0.910245    1.029510
# 75%           6.243750        0.052300                  1.158448    1.214405
# max           7.587000        0.136930                  1.690420    1.402230
#
#        Health (Life Expectancy)     Freedom  Trust (Government Corruption)  \
# count                158.000000  158.000000                     158.000000
# mean                   0.630259    0.428615                       0.143422
# ...

# %% [markdown]
# # EDA

# %%
df.corr()
# Out:
#                                Happiness Score  Standard Error  \
# Happiness Score                       1.000000       -0.177254
# Standard Error                       -0.177254        1.000000
# Economy (GDP per Capita)              0.780966       -0.217651
# Family                                0.740605       -0.120728
# Health (Life Expectancy)              0.724200       -0.310287
# Freedom                               0.568211       -0.129773
# Trust (Government Corruption)         0.395199       -0.178325
# Generosity                            0.180319       -0.088439
# Dystopia Residual                     0.530474        0.083981
#
#                                Economy (GDP per Capita)    Family  \
# Happiness Score                                0.780966  0.740605
# Standard Error                                -0.217651 -0.120728
# Economy (GDP per Capita)                       1.000000  0.645299
# Family                                         0.645299  1.000000
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# lighter color shows high corelation.
# from above observation it is cleared that happiness score is highly corelated with
# 1.economy
# 2.family
# 3.health

# %%
sns.pairplot(df)

# %%
sns.jointplot(x='Happiness Score',y='Standard Error',data=df)

# %%
sns.scatterplot(x='Happiness Score',y='Economy (GDP per Capita)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Economy (GDP per Capita)'>

# %% [markdown]
# As economy increases happiness score will also increases

# %%
sns.scatterplot(x='Happiness Score',y='Family',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Family'>

# %% [markdown]
# happiness score increases with increasing the value of family

# %%
sns.scatterplot(x='Happiness Score',y='Health (Life Expectancy)',data=df)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %% [markdown]
# happiness score increases with increase in health

# %%
sns.scatterplot(x='Economy (GDP per Capita)',y='Health (Life Expectancy)',data=df)
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Health (Life Expectancy)'>

# %% [markdown]
# Health increases as economy increases

# %% [markdown]
# # Skewness

# %%
skew=df.skew()
skew
# Out:
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# standerd error, family, trust and generosity are highly skewed data

# %%
columns=list(enumerate(df.columns))
columns
# Out:
# [(0, 'Happiness Score'),
#  (1, 'Standard Error'),
#  (2, 'Economy (GDP per Capita)'),
#  (3, 'Family'),
#  (4, 'Health (Life Expectancy)'),
#  (5, 'Freedom'),
#  (6, 'Trust (Government Corruption)'),
#  (7, 'Generosity'),
#  (8, 'Dystopia Residual')]

# %%
plt.figure(figsize=(10,15))
for i in columns:
    plt.subplot(3,3,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()

# %% [markdown]
# from above graph it is clearly shown that standerd error, family, trust and generosity are highly skewed data

# %% [markdown]
# # checking for outliers

# %%
plt.figure(figsize=(10,15))
for i in columns:
    plt.subplot(3,3,i[0]+1)
    sns.boxplot(df[i[1]])
plt.show()

# %% [markdown]
# standerd error,trust have large amount of outliers while family , generosity and dystopia residual are also have outliers

# %% [markdown]
# # outlier removing

# %% [markdown]
# # using zscore

# %%
from scipy.stats import zscore

# %%
zscore_outliers=np.abs(zscore(df))
zscore_outliers
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)    Family  \
# 0           1.937360        0.805926                  1.369621  1.320281
# 1           1.914581        0.055889                  1.135226  1.514458
# 2           1.884792        0.854487                  1.192861  1.361054
# 3           1.880411        0.531526                  1.525130  1.251922
# 4           1.797179        0.722845                  1.194876  1.221204
# ..               ...             ...                       ...       ...
# 153         1.674055        0.774917                  1.552987  0.800520
# 154         1.783571        0.662582                  1.392303  2.346860
# 155         2.076199        0.132534                  0.455245  1.901086
# 156         2.164688        2.263962                  2.067566  2.118467
# 157         2.222513        1.134182                  1.586334  3.134725
#
#      Health (Life Expectancy)   Freedom  Trust (Government Corruption)  \
# ...

# %%
threshold=3
print('Outliers:- ',np.where(zscore_outliers>3))
# Out:
# Outliers:-  (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64), array([6, 1, 1, 1, 7, 3, 6, 8, 3], dtype=int64))

# %%
df_zscore=df[(zscore_outliers<3).all(axis=1)]

# %%
print("shape of original dataframe: ",df.shape)
print("shape of dataframe using zscore: ",df_zscore.shape)
print("removal of rows: ",df.shape[0]-df_zscore.shape[0])
# Out:
# shape of original dataframe:  (158, 9)
# shape of dataframe using zscore:  (149, 9)
# removal of rows:  9

# %% [markdown]
# # using IQR

# %%
from scipy import stats

# %%
IQR=stats.iqr(df)
IQR
# Out:
# 1.0912775

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR = df[~ ((df < (Q1 -1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print("shape of original dataframe: ",df.shape)
print("shape of dataframe using zscore: ",IQR.shape)
print("removal of rows: ",df.shape[0]-IQR.shape[0])
# Out:
# shape of original dataframe:  (158, 9)
# shape of dataframe using zscore:  (157, 9)
# removal of rows:  1

# %% [markdown]
# by comparing zscore and IQR method, rows removal in IQR is less.
# so we are using IQR method

# %%
df=IQR
df.shape
# Out:
# (157, 9)

# %% [markdown]
# # skewness removal

# %%
df_corr=df.corr()

# %%
df_corr['Happiness Score']
# Out:
# Happiness Score                  1.000000
# Standard Error                  -0.164471
# Economy (GDP per Capita)         0.776983
# Family                           0.730683
# Health (Life Expectancy)         0.720207
# Freedom                          0.571561
# Trust (Government Corruption)    0.397340
# Generosity                       0.175369
# Dystopia Residual                0.526720
# Name: Happiness Score, dtype: float64

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# from above observation it is observe that economy, family and health are highly corelated with happiness score

# %%
df.skew()
# Out:
# Happiness Score                  0.132185
# Standard Error                   2.014320
# Economy (GDP per Capita)        -0.329059
# Family                          -0.952032
# Health (Life Expectancy)        -0.725796
# Freedom                         -0.420609
# Trust (Government Corruption)    1.376728
# Generosity                       0.992192
# Dystopia Residual               -0.253134
# dtype: float64

# %% [markdown]
# standerd error, family, health, trust, generosity are skewed data. But we are removing the skewness of that collumn which are not much corelated with our target column. so we have to remove skewness from standerd erroe, trust and generosity

# %%
#selecting column to remove skewness
skewed_column=['Standard Error', 'Trust (Government Corruption)', 'Generosity']
print('Before removing skewness:-')
plt.figure(figsize=(12,19))
for i in enumerate(skewed_column):
    plt.subplot(5,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# Before removing skewness:-

# %%
# removing skewness:-

df[['Standard Error','Trust (Government Corruption)','Generosity']]=np.sqrt(df[['Standard Error','Trust (Government Corruption)', 'Generosity']])
print('After removing skewness:-')
plt.figure(figsize=(12,19))
for i in enumerate(skewed_column):
    plt.subplot(5,2,i[0]+1)
    sns.distplot(df[i[1]])
plt.show()
# Out:
# After removing skewness:-

# %%
df.skew()
# Out:
# Happiness Score                  0.132185
# Standard Error                   1.251489
# Economy (GDP per Capita)        -0.329059
# Family                          -0.952032
# Health (Life Expectancy)        -0.725796
# Freedom                         -0.420609
# Trust (Government Corruption)    0.503645
# Generosity                      -0.138906
# Dystopia Residual               -0.253134
# dtype: float64

# %% [markdown]
# we observe from above observation, skewness was removed from targeted three column

# %% [markdown]
# # Model selection

# %% [markdown]
# # diving data in x and y

# %%
x=df.drop(['Happiness Score'],axis=1)
x.shape
# Out:
# (157, 8)

# %%
y=df['Happiness Score']
y.shape
# Out:
# (157,)

# %%
# importing libraries for model selecting
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# # splitting data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.33,random_state=42)
x_train.shape
# Out:
# (105, 8)

# %%
x_test.shape
# Out:
# (52, 8)

# %%
y_train.shape
# Out:
# (105,)

# %%
y_test.shape
# Out:
# (52,)

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.coef_
# Out:
# array([-0.06427607,  1.02010074,  1.00232353,  1.030289  ,  1.00426898,
#         0.76453117,  0.90274509,  0.98763967])

# %%
lr.intercept_
# Out:
# -0.30572951137591176

# %%
lr.score(x_train,y_train)
# Out:
# 0.9984650987986898

# %%
#predict the value
pred=lr.predict(x_test)
print("predicted happiness score : ",pred)
print("actual score : ", y_test)
# Out:
# predicted happiness score :  [4.33511975 6.04162749 4.19011303 4.01039929 4.72153995 6.59813409
#  4.87945629 4.93938613 4.98927738 3.97490579 6.90287943 5.85928004
#  7.01307241 5.56502731 6.82365299 6.49342521 4.37033184 4.72385249
#  3.01071962 5.75764866 4.50617765 6.98945027 7.24193517 7.25840808
#  6.52445703 5.22879667 5.85145887 4.14664161 3.77596139 4.86345782
#  3.68319615 5.3743481  4.03832418 5.72067895 4.40560663 5.145287
#  4.82142639 6.14689505 5.61479145 4.35273233 6.70152808 4.07723564
#  5.24452139 3.66506573 6.29776786 5.28364366 6.7996789  4.25780633
#  3.94269518 7.2618042  5.23333302 5.5887142 ]
# actual score :  126    4.350
# 45     5.987
# 133    4.218
# 138    3.989
# 111    4.677
# 29     6.574
# 95     4.949
# 97     4.885
# 94     4.959
# 139    3.956
# 19     6.901
# 56     5.828
# 15     6.983
# 69     5.548
# 24     6.786
# 30     6.505
# 125    4.369
# 108    4.694
# 155    3.006
# 65     5.695
# 119    4.517
# 18     6.937
# 12     7.200
# ...

# %%
# printing errors
print("Errors:")
print("Mean absolute error : ",mean_absolute_error(y_test,pred))
print("Mean squared error : ",mean_squared_error(y_test,pred))
print("Root mean squared error : ",np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# Errors:
# Mean absolute error :  0.027940002265156583
# Mean squared error :  0.0015630691266836547
# Root mean squared error :  0.03953566904307621

# %%
print("r2 score : ",r2_score(y_test,pred))
# Out:
# r2 score :  0.9987315625255464

# %% [markdown]
# # support vector regressor

# %%
from sklearn.svm import SVR

# %% [markdown]
# in SVC 3 types of kernel are present . so we check for all three kernel

# %% [markdown]
# 1. linear

# %%
sv=SVR(kernel='linear')
sv.fit(x_train,y_train)
print(sv.score(x_train,y_train))
sv1_pred=sv.predict(x_test)
# Out:
# 0.9958797272154701

# %%
print('Mean squared error using linear kernel:',mean_squared_error(sv1_pred,y_test))
print('M absolute error using linear kernel:',mean_absolute_error(sv1_pred,y_test))
print('r2_score using linear kernel:',r2_score(sv1_pred,y_test))
# Out:
# Mean squared error using linear kernel: 0.005109052017935268
# M absolute error using linear kernel: 0.06562248357959491
# r2_score using linear kernel: 0.9957863201469718

# %% [markdown]
# 2. poly

# %%
sv=SVR(kernel='poly')
sv.fit(x_train,y_train)
print(sv.score(x_train,y_train))
sv1_pred2=sv.predict(x_test)
print('Mean squared error using poly kernel:',mean_squared_error(sv1_pred2,y_test))
print('M absolute error using poly kernel:',mean_absolute_error(sv1_pred2,y_test))
print('r2_score using poly kernel:',r2_score(sv1_pred,y_test))
# Out:
# 0.974600709698598
# Mean squared error using poly kernel: 0.043033632043900774
# M absolute error using poly kernel: 0.16605420397877443
# r2_score using poly kernel: 0.9957863201469718

# %% [markdown]
# 3. rbf

# %%
sv=SVR(kernel='rbf')
sv.fit(x_train,y_train)
print(sv.score(x_train,y_train))
sv1_pred3=sv.predict(x_test)
print('Mean squared error using poly kernel:',mean_squared_error(sv1_pred3,y_test))
print('M absolute error using poly kernel:',mean_absolute_error(sv1_pred3,y_test))
print('r2_score using poly kernel:',r2_score(sv1_pred3,y_test))
# Out:
# 0.9914501623484269
# Mean squared error using poly kernel: 0.027425687851492925
# M absolute error using poly kernel: 0.09364689532164297
# r2_score using poly kernel: 0.9768184399823412

# %% [markdown]
# According to all metrics score selecting the SVR(kernel='poly') as best model

# %% [markdown]
# # elastic net regression

# %%
from sklearn.linear_model import ElasticNet

# %%
enr=ElasticNet(alpha=0.0001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print('enr score with alpha=0.0001',enr.score(x_train,y_train))
print('Mean squared error with alpha=0.0001:',mean_squared_error(enrpred,y_test))
print('M absolute error with alpha=0.0001:',mean_absolute_error(enrpred,y_test))
print('r2_score with alpha=0.0001:',r2_score(enrpred,y_test))
# Out:
# enr score with alpha=0.0001 0.9984632941075653
# Mean squared error with alpha=0.0001: 0.0015698545190636916
# M absolute error with alpha=0.0001: 0.028134618662435964
# r2_score with alpha=0.0001: 0.9987424869859463

# %%
enr=ElasticNet(alpha=0.001)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print('enr score with alpha=0.001: ',enr.score(x_train,y_train))
print('Mean squared error with alpha=0.001:',mean_squared_error(enrpred,y_test))
print('M absolute error with alpha=0.001:',mean_absolute_error(enrpred,y_test))
print('r2_score with alpha=0.001:',r2_score(enrpred,y_test))
# Out:
# enr score with alpha=0.001:  0.9983937979550686
# Mean squared error with alpha=0.001: 0.0016481158138625769
# M absolute error with alpha=0.001: 0.029603704293830028
# r2_score with alpha=0.001: 0.9986680668093341

# %%
enr=ElasticNet(alpha=0.01)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print('enr score with alpha=0.01: ',enr.score(x_train,y_train))
print('Mean squared error with alpha=0.01:',mean_squared_error(enrpred,y_test))
print('M absolute error with alpha=0.01:',mean_absolute_error(enrpred,y_test))
print('r2_score with alpha=0.01:',r2_score(enrpred,y_test))
# Out:
# enr score with alpha=0.01:  0.993189554158976
# Mean squared error with alpha=0.01: 0.008413891309451612
# M absolute error with alpha=0.01: 0.0705632343278069
# r2_score with alpha=0.01: 0.9926168183894598

# %%
enr=ElasticNet(alpha=0.1)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print('enr score with alpha=0.1: ',enr.score(x_train,y_train))
print('Mean squared error with alpha=0.1:',mean_squared_error(enrpred,y_test))
print('M absolute error with alpha=0.1:',mean_absolute_error(enrpred,y_test))
print('r2_score with alpha=0.1:',r2_score(enrpred,y_test))
# Out:
# enr score with alpha=0.1:  0.8377391925699952
# Mean squared error with alpha=0.1: 0.1988297107395634
# M absolute error with alpha=0.1: 0.377447325804054
# r2_score with alpha=0.1: 0.651729755074824

# %%
enr=ElasticNet(alpha=0.1)
enr.fit(x_train,y_train)
enrpred=enr.predict(x_test)
print('enr score with alpha=0.1: ',enr.score(x_train,y_train))
print('Mean squared error with alpha=0.1:',mean_squared_error(enrpred,y_test))
print('M absolute error with alpha=0.1:',mean_absolute_error(enrpred,y_test))
print('r2_score with alpha=0.1:',r2_score(enrpred,y_test))
# Out:
# enr score with alpha=0.1:  0.8377391925699952
# Mean squared error with alpha=0.1: 0.1988297107395634
# M absolute error with alpha=0.1: 0.377447325804054
# r2_score with alpha=0.1: 0.651729755074824

# %% [markdown]
# r2 score and root mean squared score are always higher when we use different alpha, so this regresssion is not suitable

# %% [markdown]
# # saving the model

# %%
import joblib
# save the model as object file
joblib.dump(sv1_pred2,'happiness_score_prediction.obj')
